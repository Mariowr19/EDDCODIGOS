# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariowr19/EDDCODIGOS/blob/master/Listas%20simplemente%20ligadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Nodo:
  def __init__(self,dato):
    self.__dato = dato
    self.__siguiente = None

  def get_dato(self):
    return self.__dato

  def set_dato(self, d):
    self.__dato = d

  def get_siguiente(self):
    return self.__siguiente

  def set_siguiente(self, d):
    self.__siguiente = d

  def to_string(self):
    return "l " + str(self.__dato) + " l " + str(self.__siguiente) + " l --->"

  def show( self ):
    curr_node = self # Head
    print(" Inicio de la estructura ligada:")
    print("|" + str(curr_node.get_dato()) + "| -->" , end ="" )
    while( curr_node.get_siguiente() != None ):
        curr_node = curr_node.get_siguiente()
        print("|" + str(curr_node.get_dato() ) + "| -->" , end ="" )
    print("\nFin")

  #Ejemplo 1
a = Nodo(10)
a.show()

  #Ejemplo 2
a.set_siguiente(Nodo(20))
a.show()

  #Ejemplo 3
a.get_siguiente().set_siguiente(Nodo(30))
a.show()

  #Ejemplo 4
a.get_siguiente().get_siguiente().set_siguiente(Nodo(40))
a.show()

  #Ejemplo 5
a.get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(50))
a.show()

  #Ejemplo 6
a.set_dato(12)
a.show()

  #Ejemplpo 7
a.get_siguiente().get_siguiente().get_siguiente().set_dato(45)
a.show()

  #Ejemplo 8
a.get_siguiente().get_siguiente().get_siguiente().get_siguiente().set_siguiente(Nodo(60))
a.show()

  #Ejemplo 9
a.get_siguiente().set_dato(25)
a.show()
# Out:
#  Inicio de la estructura ligada:
# |10| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->|40| -->
# Fin
#  Inicio de la estructura ligada:
# |10| -->|20| -->|30| -->|40| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|40| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|45| -->|50| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|20| -->|30| -->|45| -->|50| -->|60| -->
# Fin
#  Inicio de la estructura ligada:
# |12| -->|25| -->|30| -->|45| -->|50| -->|60| -->
# Fin

# %%
class Nodo:
  def __init__(self,dato):
    self.dato = dato
    self.siguiente = None

  #Ejemplo 1
a = Nodo(10)

print(a.dato)
print(a.siguiente)

  #Ejemplo 2
a.siguiente = Nodo(20)

  #Ejemplo 3
a.siguiente.siguiente = Nodo(30)

  #Ejemplo 4
a.siguiente.siguiente.siguiente = Nodo(40)
  
  #Ejemplo 5
a.siguiente.siguiente.siguiente.siguiente = Nodo(50)

#Recorrido transversal
curr_node = a
print(curr_node.dato , '-->' , end='')
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

  #Ejemplo 6
a.siguiente.siguiente.siguiente.dato = 45

  #Ejemplo 7
a.siguiente.siguiente.dato = 35

  #Ejemplo 8
a.siguiente.siguiente = a.siguiente.siguiente.siguiente

  #Ejemplo 9
a.siguiente = a.siguiente.siguiente.siguiente.siguiente


#Recorrido transversal
curr_node = a
print(curr_node.dato , '-->' , end='')
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")
# Out:
# 10
# None
# 10 -->20 -->30 -->40 -->50 -->
# 10 -->

# %%
#Codigo de 18 de noviembre.
class Nodo:
  def __init__(self,dato, siguiente=None ):
    self.dato = dato
    self.siguiente = siguiente

head = Nodo( 10 , Nodo( 20 , Nodo( 30  , Nodo( 40 , Nodo( 50 ) ) ) ) )

#Recorrido transversal
curr_node = head
print(curr_node.dato , '-->' , end='')
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

#insertar el nodo 35 despues de 30.
anterior = head.siguiente.siguiente
print(anterior.dato)

Nuevo = Nodo( 35 )
Nuevo.siguiente = anterior.siguiente
print(Nuevo.siguiente.dato)

anterior.siguiente = Nuevo

#Recorrido transversal
curr_node = head
print(curr_node.dato , '-->' , end='')
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")

#Eliminar el Nodo 20.
head.siguiente = head.siguiente.siguiente

#Recorrido transversal
curr_node = head
print(curr_node.dato , '-->' , end='')
while( curr_node.siguiente != None ):
    curr_node = curr_node.siguiente
    print(curr_node.dato, "-->" , end="")
print("")
# Out:
# 10 -->20 -->30 -->40 -->50 -->
# 30
# 40
# 10 -->20 -->30 -->35 -->40 -->50 -->
# 10 -->30 -->35 -->40 -->50 -->

# %%
class Nodo:
  def __init__(self,dato, siguiente=None ):
    self.dato = dato
    self.siguiente = siguiente

class linkedList:
    def __init__( self ):
        self.__head = None

    def is__empty( self ):
        return self.__head == None

    def tail( self ):
        curr_node = self.__head
        while curr_node != None and curr_node.siguiente != None:
            curr_node = curr_node.siguiente
        return curr_node
    def append (self, value ):
        nuevo  = Nodo( value )
        if self.__head == None:
            self.__head = nuevo
        else:
            self.tail().siguiente = nuevo
    def transversal ( self ):
        curr_node = self.__head
        if curr_node == None:
            print("Lista vacia")
        else:
            while curr_node != None:
                print(f"{curr_node.dato} --> " , end="")
                curr_node = curr_node.siguiente
        print("")

    def preppend ( self , value ):
        nuevo = Nodo( value )
        if self.__head == None:
            self.__head == nuevo
        else:
            x = self.__head 
            self.__head = nuevo
            nuevo.siguiente = x
    def remove(self,value):
        if self.__head.dato == value:#Esto es por si el elemento es head
        self.__head = self.__head.siguiente
        return None

		curr_node = self.__head
		coincidencia = False
		while( curr_node.siguiente != None ):
			if curr_node.siguiente.dato == value:
				curr_node.siguiente = curr_node.siguiente.siguiente
				coincidencia = True
				break
			else:
				curr_node = curr_node.siguiente
		if coincidencia == False:
			print('No hay coincidencias') 

	def pop(self,pos=-1):
		'''obtener el valor en la posición específica'''
		if 0 == pos:#Esto es por si el elemento es head
			x = self.__head.dato
			self.__head = self.__head.siguiente
			return x

		cont = 0
		curr_node = self.__head

		while( curr_node.siguiente != None ):

			if cont+1 == pos:
				x = curr_node.siguiente.dato
				curr_node.siguiente = curr_node.siguiente.siguiente
				return x

			elif pos == -1 and curr_node.siguiente.siguiente == None:#En caso de que no ponga una posición se elimina el último valor
				x = curr_node.siguiente.dato
				curr_node.siguiente = curr_node.siguiente.siguiente
				return x
			elif curr_node.siguiente.siguiente == None or pos < 0 and pos != -1:
				return 'Posición excede los valores'
			else:
				cont +=1
				curr_node = curr_node.siguiente

# %%
l = linkedList()
print(f"l está vacia? = {l.is__empty() }")
x = l.tail()
print(x)
l.append (10)
l.append (20)
l.append (30)
l.append (40)
l.transversal()
l.preppend (5)
l.transversal()
l.remove(30)
l.transversal()
print(l.pop(0))
l.transversal()
print(l.pop())
l.transversal() 
print(l.pop(10))
l.transversal()
